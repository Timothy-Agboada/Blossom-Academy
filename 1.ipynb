# %%
import pandas as pd

# %%
data = pd.read_csv('Data/pew.csv')

# %%
data
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4         Dont know/refused     15       14       15       11       10
# 5         Evangelical Prot     575      869     1064      982      881
# 6                    Hindu       1        9        7        9       11
# 7  Historically Black Prot     228      244      236      238      197
# 8         Jehovahs Witness      20       27       24       24       21
# 9                   Jewish      19       19       25       25       30
#
#    $50-75k
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95

# %%
data = data.rename(columns={
    '$10-20k':'\$10k-\$20k','$20-30k':'\$20k-\$30k','$30-40k':'\$30k-\$40k','$40-50k':'\$40k-\$50k','$50-75k':'\$50k-\$75k'
})

# %%
data
# Out:
#                    religion  <$10k  \$10k-\$20k  \$20k-\$30k  \$30k-\$40k  \
# 0                  Agnostic     27           34           60           81
# 1                   Atheist     12           27           37           52
# 2                  Buddhist     27           21           30           34
# 3                  Catholic    418          617          732          670
# 4         Dont know/refused     15           14           15           11
# 5         Evangelical Prot     575          869         1064          982
# 6                    Hindu       1            9            7            9
# 7  Historically Black Prot     228          244          236          238
# 8         Jehovahs Witness      20           27           24           24
# 9                   Jewish      19           19           25           25
#
#    \$40k-\$50k  \$50k-\$75k
# 0           76          137
# 1           35           70
# 2           33           58
# 3          638         1116
# ...

# %%
data.index.name = 'religion_id'

# %%
data = data.reset_index()

# %%
data
# Out:
#    religion_id                  religion  <$10k  \$10k-\$20k  \$20k-\$30k  \
# 0            0                  Agnostic     27           34           60
# 1            1                   Atheist     12           27           37
# 2            2                  Buddhist     27           21           30
# 3            3                  Catholic    418          617          732
# 4            4         Dont know/refused     15           14           15
# 5            5         Evangelical Prot     575          869         1064
# 6            6                    Hindu       1            9            7
# 7            7  Historically Black Prot     228          244          236
# 8            8         Jehovahs Witness      20           27           24
# 9            9                   Jewish      19           19           25
#
#    \$30k-\$40k  \$40k-\$50k  \$50k-\$75k
# 0           81           76          137
# 1           52           35           70
# ...

# %%
data1 = pd.melt(data, id_vars=['religion_id', 'religion'],
               value_name='frequency', var_name='income_range')
data1 = data1.sort_values(['religion_id', 'religion'])

# %%
data1
# Out:
#     religion_id                  religion income_range  frequency
# 0             0                  Agnostic        <$10k         27
# 10            0                  Agnostic  \$10k-\$20k         34
# 20            0                  Agnostic  \$20k-\$30k         60
# 30            0                  Agnostic  \$30k-\$40k         81
# 40            0                  Agnostic  \$40k-\$50k         76
# 50            0                  Agnostic  \$50k-\$75k        137
# 1             1                   Atheist        <$10k         12
# 11            1                   Atheist  \$10k-\$20k         27
# 21            1                   Atheist  \$20k-\$30k         37
# 31            1                   Atheist  \$30k-\$40k         52
# 41            1                   Atheist  \$40k-\$50k         35
# 51            1                   Atheist  \$50k-\$75k         70
# 2             2                  Buddhist        <$10k         27
# ...

# %%
data1.dtypes
# Out:
# religion_id      int64
# religion        object
# income_range    object
# frequency        int64
# dtype: object

# %%
del data1['religion_id']

# %%
 data1.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_d5251d02_51bc_11ea_8e29_47441eb17631" ><thead>    <tr>        <th class="col_heading level0 col0" >religion</th>        <th class="col_heading level0 col1" >income_range</th>        <th class="col_heading level0 col2" >frequency</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d5251d02_51bc_11ea_8e29_47441eb17631row0_col0" class="data row0 col0" >Agnostic</td>
#                         <td id="T_d5251d02_51bc_11ea_8e29_47441eb17631row0_col1" class="data row0 col1" ><$10k</td>
#                         <td id="T_d5251d02_51bc_11ea_8e29_47441eb17631row0_col2" class="data row0 col2" >27</td>
#             </tr>
#             <tr>
#                                 <td id="T_d5251d02_51bc_11ea_8e29_47441eb17631row1_col0" class="data row1 col0" >Agnostic</td>
#                         <td id="T_d5251d02_51bc_11ea_8e29_47441eb17631row1_col1" class="data row1 col1" >\$10k-\$20k</td>
# ...
